# %%
import pandas as pd
from pandas.io.json import json_normalize
from numpy import loadtxt
import data_handling as file_dh
import pred_model as file_pred_mdl

cumtd_df = pd.read_csv("Mar30_twilight_WITH_CORR.csv")
# cumtd_df = cumtd_df_temp.drop(["Unnamed: 0", "id"], axis = 1)
cumtd_df
# Out:
# D:\Anaconda\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#          Unnamed: 0           query_time    stop_id         headsign  \
# 0                 0  2021-02-22 12:38:01       IU:1       13N Silver
# 1                 1  2021-02-22 12:38:01       IU:9       13S Silver
# 2                 2  2021-02-22 12:38:01       IU:1        8E Bronze
# 3                 3  2021-02-22 12:38:01       IU:9       22S Illini
# 4                 4  2021-02-22 12:38:01       IU:1           2U Red
# ...             ...                  ...        ...              ...
# 1281606     1281606  2021-03-03 15:10:04  WLNTLGN:1         5W Green
# 1281607     1281607  2021-03-03 15:10:04  WLNTLGN:2  5W Green Hopper
# 1281608     1281608  2021-03-03 15:10:04  WLNTLGN:1        6W Orange
# 1281609     1281609  2021-03-03 15:10:04  WLNTLGN:1  5W Green Hopper
# ...

# %%
cumtd_df_subset = cumtd_df.head(100000)
cumtd_df_subset
# Out:
#        Unnamed: 0           query_time    stop_id                headsign  \
# 0               0  2021-02-22 12:38:01       IU:1              13N Silver
# 1               1  2021-02-22 12:38:01       IU:9              13S Silver
# 2               2  2021-02-22 12:38:01       IU:1               8E Bronze
# 3               3  2021-02-22 12:38:01       IU:9              22S Illini
# 4               4  2021-02-22 12:38:01       IU:1                  2U Red
# ...           ...                  ...        ...                     ...
# 99995       99995  2021-02-23 07:00:04   WHT2ND:1                12W Teal
# 99996       99996  2021-02-23 07:00:04   WHT2ND:3  12E Teal Orchard Downs
# 99997       99997  2021-02-23 07:00:05  WLNTLGN:1                9B Brown
# 99998       99998  2021-02-23 07:00:05  WLNTLGN:1                 7W Grey
# 99999       99999  2021-02-23 07:00:05  WLNTLGN:1                  2C Red
#
#                                                trip_id       trip_service_id  \
# ...

# %%
cumtd_df_subset = file_dh.rolling_correlations(cumtd_df_subset, "expected_mins", "time_since_appearance")
cumtd_df_subset
# Out:
# d:\UIUC MISM Studies\2021 Spring\Independent Study\uiuc_msim_indie_study-master\data_handling.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_dataframe[new_feature_name] = -2
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# d:\UIUC MISM Studies\2021 Spring\Independent Study\uiuc_msim_indie_study-master\data_handling.py:96: SettingWithCopyWarning:
# ...

# %%
cumtd_df_subset.columns
# Out:
# Index(['Unnamed: 0', 'query_time', 'stop_id', 'headsign', 'trip_id',
#        'trip_service_id', 'trip_shape_id', 'vehicle_id', 'is_monitored',
#        'is_scheduled', 'is_istop', 'scheduled', 'expected', 'expected_mins',
#        'location_lat', 'location_long', 'is_departed', 'actual',
#        'stop_id_stem', 'stop_id_encoded', 'headsign_encoded',
#        'trip_shape_id_encoded', 'scheduled_date_only',
#        'expected_scheduled_diff', 'diff_in_sec', 'time_since_appearance',
#        'number_of_stalls', 'day_of_week', 'query_weekday_encoded',
#        'time_elapsed_since_twelve_AM', 'corr_expected_min_vs_tsa',
#        'corr_expected_mins_vs_time_since_appearance'],
#       dtype='object')

# %%
cumtd_df_subset = file_dh.obtain_avg_lateness_by_group(cumtd_df_subset, "vehicle_id")
cumtd_df_subset
# Out:
# d:\UIUC MISM Studies\2021 Spring\Independent Study\uiuc_msim_indie_study-master\data_handling.py:128: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_dataframe[new_feature_name] = -10000
# D:\Anaconda\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#        Unnamed: 0           query_time    stop_id                headsign  \
# 0               0  2021-02-22 12:38:01       IU:1              13N Silver
# ...
